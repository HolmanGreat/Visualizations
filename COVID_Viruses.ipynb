# %% [markdown]
# <a href="https://colab.research.google.com/github/HolmanGreat/Visualizations/blob/main/COVID_Viruses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import Normalizer

# %%
covid_19 = pd.read_csv('/content/covid19_variant.csv')
covid = covid_19.copy()
covid

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7790 entries, 0 to 7789
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               7790 non-null   object
#  1   area               7790 non-null   object
#  2   area_type          7790 non-null   object
#  3   variant_name       7790 non-null   object
#  4   specimens          7790 non-null   int64
#  5   percentage         7790 non-null   float64
#  6   specimens_7d_avg   7730 non-null   float64
#  7   percentage_7d_avg  7730 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 487.0+ KB

# %%
sns.catplot(x = 'variant_name',
y = 'specimens',
data = covid,
hue = 'variant_name', kind = 'bar')

plt.show()

# %%
covid['variant_name']. unique ()
# Out:
# array(['Alpha', 'Lambda', 'Other', 'Epsilon', 'Omicron', 'Beta', 'Total',
#        'Delta', 'Mu', 'Gamma'], dtype=object)

# %% [markdown]
# ### COVID-19 strains are designated by the Greek alphabets (a directive from the World Health Organization).
#
# ######Hence, 'Total' is not a type of COVID-19 variant. Instead it is a total number of the variant strains of COVID-19, detected each day.
#
# Also strains labelled 'Other' in the dataset could possibly mean other variant strains whose Greek alphabet designation is not stated.

# %%
# All the true strains (designated by the Greek alphabets)
# are allocated to the variable 'true_var'

pure_var = covid_19['variant_name']
true_var = pure_var.drop(pure_var[(covid_19['variant_name'] == 'Total')]. index)
true_var
# Out:
# 0         Alpha
# 1        Lambda
# 2         Other
# 3       Epsilon
# 4       Omicron
#          ...
# 7785     Lambda
# 7786       Beta
# 7787    Omicron
# 7788    Epsilon
# 7789      Other
# Name: variant_name, Length: 7011, dtype: object

# %%
total_strain = covid.loc[(
covid['variant_name'] == 'Total')]

covid = covid.drop(covid[(
covid['variant_name'] == 'Total')].index)

covid.head(21)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7011 entries, 0 to 7789
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               7011 non-null   object
#  1   area               7011 non-null   object
#  2   area_type          7011 non-null   object
#  3   variant_name       7011 non-null   object
#  4   specimens          7011 non-null   int64
#  5   percentage         7011 non-null   float64
#  6   specimens_7d_avg   6957 non-null   float64
#  7   percentage_7d_avg  6957 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 493.0+ KB

# %% [markdown]
# #Visualizations

# %%
# Percentage distribution of
# variant strains of COVID-19

'''percent = covid ['percentage'].values
percent = np.array(percent, dtype = np.int64)
percent = percent.reshape(1,-1)
norm = Normalizer().fit(percent)
percentage = norm.transform(percent)'''

# %%
g = sns.scatterplot(x = 'specimens',
y = 'variant_name',
hue = 'variant_name',
data = covid)
g.set(xscale = 'log')

g = plt.subplots(figsize=(6, 6))
plt.show ()

# %%
sns.set_style('darkgrid')
sns.stripplot(x = 'variant_name',
y = 'specimens',
data = covid)
plt.

plt.show()

# %%
german_data = data.loc[(data['Country'] == 'Germany') & data['Spending_USD']]

# %%
sns.relplot(x = 'Year', y = 'Spending_USD', data = german_spending, hue = 'Year')
plt.show()

# %%
sns.relplot(x = 'Year', y = 'Spending_USD', data = data, kind  = 'line')
plt.show()

# %%
data.hist()
plt.show()

# %%
sns.catplot(x = 'Year', y = 'Spending_USD', data = data, hue = 'Country')
plt.show()

# %%
country= data['Country']
spend = data['Spending_USD']

# %%
sns.histplot(data['Life_Expectancy'],
kde = True)
plt.show()

# %%
sns.displot(data['Life_Expectancy'],
kde = True)
plt.show()

# %%
sns.displot(data['Spending_USD'],
             kind='kde',
             rug=True,
             fill=True)

# Plot the results
